# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
test_df= pd.read_csv("F:/Paras/Simplilearn/titanic/test.csv")
train_df=pd.read_csv("F:/Paras/Simplilearn/titanic/train.csv")

# %%
test_df.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.699118
# std     257.353842    0.486592    0.836071    0.477990   13.002015
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    1.000000   29.699118
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare      Family
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208    1.904602
# std      1.102743    0.806057   49.693429    1.613459
# min      0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    7.910400    1.000000
# ...

# %% [markdown]
# # Finding out the Null values

# %%
print(pd.isnull(train_df).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # From above we can see that we have null values in category Age,Cabin and Embarked.
# # Now we fill the Null values in both data set i.e train and test data as below

# %%
train_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
train_df['Age'].fillna(train_df['Age'].mean(),inplace=True)
train_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
print(pd.isnull(test_df).sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df['Age'].mean()
# Out:
# 30.272590361445783

# %%
test_df['Age'].fillna(test_df['Age'].mean(),inplace=True)
test_df.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
train_df['Cabin'].fillna('C',inplace=True)
train_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
test_df['Cabin'].fillna('C',inplace=True)
test_df.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
train_df['Embarked'].fillna('S',inplace=True)
train_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
test_df['Embarked'].fillna('S', inplace=True)
test_df.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# # Feature Engineering

# %%
train_df['Sex']=train_df.Sex.apply(lambda x: 0 if x == "female" else 1)
test_df['Sex'] = test_df.Sex.apply(lambda x: 0 if x == "female" else 1)

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500     C        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250     C        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500     C        S

# %%
for name_string in train_df['Name']:
    train_df['Title']=train_df['Name'].str.extract('([A-Za-z]+)\.',expand=True)

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked Title
# 0         A/5 21171   7.2500     C        S    Mr
# 1          PC 17599  71.2833   C85        C   Mrs
# 2  STON/O2. 3101282   7.9250     C        S  Miss
# 3            113803  53.1000  C123        S   Mrs
# ...

# %%
for name_string in test_df['Name']:
    test_df['Title']=test_df['Name'].str.extract('([A-Za-z]+)\.',expand=True)

# %%
test_df.head(5)
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title
# 0  34.5      0      0   330911   7.8292     C        Q    Mr
# 1  47.0      1      0   363272   7.0000     C        S   Mrs
# 2  62.0      0      0   240276   9.6875     C        Q    Mr
# 3  27.0      0      0   315154   8.6625     C        S    Mr
# 4  22.0      1      1  3101298  12.2875     C        S   Mrs

# %%
mapping = {'Mlle': 'Miss', 'Major': 'Mr', 'Col': 'Mr', 'Sir': 'Mr', 'Don': 'Mr', 'Mme': 'Miss',
          'Jonkheer': 'Mr', 'Lady': 'Mrs', 'Capt': 'Mr', 'Countess': 'Mrs', 'Ms': 'Miss', 'Dona': 'Mrs'}

# %%
train_df.replace({'Title': mapping}, inplace=True)
test_df.replace({'Title': mapping}, inplace=True)

# %%
train_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name  Sex        Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    1  22.000000      1
# ...

# %%
train_df["Family"] = train_df["SibSp"] + train_df["Parch"] + 1

# %%
test_df["Family"]=test_df["SibSp"]+test_df["Parch"]+1

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked Title  Family
# 0         A/5 21171   7.2500     C        S    Mr       2
# 1          PC 17599  71.2833   C85        C   Mrs       2
# 2  STON/O2. 3101282   7.9250     C        S  Miss       1
# 3            113803  53.1000  C123        S   Mrs       2
# ...

# %%
final_train=train_df.drop(["Name","SibSp","Parch","Ticket","Fare", "Cabin"],axis=1)

# %%
final_test=test_df.drop(["Name","SibSp","Parch","Ticket","Fare","Cabin",],axis=1)

# %%
final_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age Embarked   Title  Family
# 0            1         0       3    1  22.000000        S      Mr       2
# 1            2         1       1    0  38.000000        C     Mrs       2
# 2            3         1       3    0  26.000000        S    Miss       1
# 3            4         1       1    0  35.000000        S     Mrs       2
# 4            5         0       3    1  35.000000        S      Mr       1
# 5            6         0       3    1  29.699118        Q      Mr       1
# 6            7         0       1    1  54.000000        S      Mr       1
# 7            8         0       3    1   2.000000        S  Master       5
# 8            9         1       3    0  27.000000        S     Mrs       3
# 9           10         1       2    0  14.000000        C     Mrs       2

# %%
final_test.head(10)
# Out:
#    PassengerId  Pclass  Sex   Age Embarked Title  Family
# 0          892       3    1  34.5        Q    Mr       1
# 1          893       3    0  47.0        S   Mrs       2
# 2          894       2    1  62.0        Q    Mr       1
# 3          895       3    1  27.0        S    Mr       1
# 4          896       3    0  22.0        S   Mrs       3
# 5          897       3    1  14.0        S    Mr       1
# 6          898       3    0  30.0        Q  Miss       1
# 7          899       2    1  26.0        S    Mr       3
# 8          900       3    0  18.0        C   Mrs       1
# 9          901       3    1  21.0        S    Mr       3

# %%
# How many Passengers Survived
print(train_df.Survived.value_counts())
sns.countplot(x='Survived',data=train_df)
plt.show()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#How many male and female survived.
print(train_df.groupby('Sex')['Survived'].sum())
sns.countplot(x='Survived',hue='Sex',data=train_df)
plt.show()
# Out:
# Sex
# 0    233
# 1    109
# Name: Survived, dtype: int64

# %%
#Find the Survivers based on Title
print(train_df.groupby('Title')['Survived'].sum())
sns.countplot(x='Survived',hue='Title',data=train_df)
plt.show()
# Out:
# Title
# Dr          3
# Master     23
# Miss      131
# Mr         84
# Mrs       101
# Rev         0
# Name: Survived, dtype: int64

# %%
#Find the survivers based on Class
print(train_df.groupby('Pclass')['Survived'].sum())
sns.countplot(x='Survived',hue='Pclass',data=train_df)
plt.show()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
#Lets see the corelation matrix cofficient.
plt.figure(figsize=(8,6))
sns.heatmap(train_df.corr(),annot=True)
plt.show()

# %%
final_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age Embarked Title  Family
# 0            1         0       3    1  22.0        S    Mr       2
# 1            2         1       1    0  38.0        C   Mrs       2
# 2            3         1       3    0  26.0        S  Miss       1
# 3            4         1       1    0  35.0        S   Mrs       2
# 4            5         0       3    1  35.0        S    Mr       1

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5 ,"Dr":6,"Rev":7}
final_test.replace({'Title': title_mapping}, inplace=True)
final_test.head(10)
# Out:
#    PassengerId  Pclass  Sex   Age Embarked  Title  Family
# 0          892       3    1  34.5        Q      1       1
# 1          893       3    0  47.0        S      3       2
# 2          894       2    1  62.0        Q      1       1
# 3          895       3    1  27.0        S      1       1
# 4          896       3    0  22.0        S      3       3
# 5          897       3    1  14.0        S      1       1
# 6          898       3    0  30.0        Q      2       1
# 7          899       2    1  26.0        S      1       3
# 8          900       3    0  18.0        C      3       1
# 9          901       3    1  21.0        S      1       3

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5 ,"Dr":6,"Rev":7}
final_train.replace({'Title': title_mapping}, inplace=True)
final_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age Embarked  Title  Family
# 0            1         0       3    1  22.000000        S      1       2
# 1            2         1       1    0  38.000000        C      3       2
# 2            3         1       3    0  26.000000        S      2       1
# 3            4         1       1    0  35.000000        S      3       2
# 4            5         0       3    1  35.000000        S      1       1
# 5            6         0       3    1  29.699118        Q      1       1
# 6            7         0       1    1  54.000000        S      1       1
# 7            8         0       3    1   2.000000        S      4       5
# 8            9         1       3    0  27.000000        S      3       3
# 9           10         1       2    0  14.000000        C      3       2

# %%
map={"S":0,"C":1,"Q":2}
final_test.replace({'Embarked':map},inplace=True)
final_test.head(5)
# Out:
#    PassengerId  Pclass  Sex   Age  Embarked  Title  Family
# 0          892       3    1  34.5         2      1       1
# 1          893       3    0  47.0         0      3       2
# 2          894       2    1  62.0         2      1       1
# 3          895       3    1  27.0         0      1       1
# 4          896       3    0  22.0         0      3       3

# %%
map={"S":0,"C":1,"Q":2}
final_train.replace({'Embarked':map},inplace=True)
final_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  Embarked  Title  Family
# 0            1         0       3    1  22.0         0      1       2
# 1            2         1       1    0  38.0         1      3       2
# 2            3         1       3    0  26.0         0      2       1
# 3            4         1       1    0  35.0         0      3       2
# 4            5         0       3    1  35.0         0      1       1

# %%
from sklearn.model_selection import train_test_split

predictors = final_train.drop(['Survived'], axis=1)
target = final_train["Survived"]
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.22, random_state = 0)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_val)
acc_logreg = round(logreg.score(x_train, y_train) * 100, 2)
acc_logreg
# Out:
# 82.13

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(x_train, y_train)
random_forest.score(x_train, y_train)
y_pred = random_forest.predict(x_val)
acc_random_forest = round(random_forest.score(x_train, y_train) * 100, 2)
acc_random_forest
# Out:
# 99.86

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC,LinearSVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_val)
acc_svc = round(svc.score(x_train, y_train) * 100, 2)
acc_svc
# Out:
# 99.28

# %% [markdown]
# # Decison Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier


decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train, y_train)
y_pred = decision_tree.predict(x_val)
acc_decision_tree = round(decision_tree.score(x_train, y_train) * 100, 2)
acc_decision_tree
# Out:
# 100.0

# %%
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
model=decision_tree
model.score(x_train,y_train)
# Out:
# 1.0

# %%
predictions = decision_tree.predict(final_test)

# %%
submission = pd.DataFrame({'PassengerId':final_test['PassengerId'],'Survived':predictions})
submission.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         1
# 4          896         1
# 5          897         0
# 6          898         0
# 7          899         0
# 8          900         1
# 9          901         0

# %%
filename = 'Titanic Survival Pred.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: Titanic Survival Pred.csv
